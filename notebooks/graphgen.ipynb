# %%
import time, enum, math
from collections import defaultdict
from typing import Tuple

import numpy as np
import networkx as nx
import matplotlib as plt

import sys
sys.path.insert(0, "../")
sys.path.insert(1, "../lib")

from lib.networkgen import Network, NetworkType

# %%
def test_caveman():
    G = Network.generate(NetworkType.CAVEMAN, (5, 7))
    Network.visualize(NetworkType.CAVEMAN, G)

test_caveman()

# %%
def test_gaussian_random_partition():
    G = Network.generate(NetworkType.GAUSSIAN_RANDOM_PARTITION, (30, 5, 20, 0.9, 0.05))
    Network.visualize(NetworkType.GAUSSIAN_RANDOM_PARTITION, G)
    #nx.draw_circular(G)

test_gaussian_random_partition()

# %%
def test_windmill():
    G = Network.generate(NetworkType.WINDMILL, (30, 5))
    #visualize(GraphType.WINDMILL, G)
    nx.draw_spring(G)

test_windmill()

# %%
def test_smallworld():
    G = Network.generate(NetworkType.SMALLWORLD, (20, 4, 0.2))
    Network.visualize(NetworkType.SMALLWORLD, G)
    #nx.draw_circular(G)

test_smallworld()
