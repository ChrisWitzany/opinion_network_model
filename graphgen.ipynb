# %%
import time, enum, math
from collections import defaultdict
from typing import Tuple

import numpy as np
import networkx as nx
import matplotlib as plt

from graphgen import generate, visualize, GraphType

# %%
def test_caveman():
    G = generate(GraphType.CAVEMAN, (5, 7))
    visualize(GraphType.CAVEMAN, G)

test_caveman()

# %%
def test_gaussian_random_partition():
    G = generate(GraphType.GAUSSIAN_RANDOM_PARTITION, (30, 5, 20, 0.9, 0.05))
    visualize(GraphType.GAUSSIAN_RANDOM_PARTITION, G)
    #nx.draw_circular(G)

test_gaussian_random_partition()

# %%
def test_windmill():
    G = generate(GraphType.WINDMILL, (30, 5))
    #visualize(GraphType.WINDMILL, G)
    nx.draw_spring(G)

test_windmill()

# %%
def test_smallworld():
    G = generate(GraphType.SMALLWORLD, (20, 4, 0.2))
    visualize(GraphType.SMALLWORLD, G)
    #nx.draw_circular(G)

test_smallworld()
